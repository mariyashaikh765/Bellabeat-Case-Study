# %% [markdown]
# # Analyzing the Data:

# %% [markdown]
# ### Importing the necessary libraries:

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Let's take a look of our dataset:

# %%
da=pd.read_csv('C:\\Users\\SHAIKH MARIYA\\New folder\\dailyActivity_merged_new.csv')
da.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   04-12-2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# ### Analysis of the values to make Decisions:

# %%
da.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %% [markdown]
# #### 1)The Average Steps walked by the customers is 7637.91
# #### 2)The Average Very Active minutes of the customers is 21 minutes
# #### 3)The Average Calories burned by the cutomers is 2303.60

# %%
plt.scatter(da['TotalSteps'], da['Calories'])
plt.xlabel('Total Steps')
plt.ylabel('Calories')
plt.show()

# %% [markdown]
# #### We can see there is a positive relationship between Total Steps and Calories Burned by the cutomers

# %% [markdown]
# ## Analyzing the Hourly Steps:

# %%
hs=pd.read_csv('C:\\Users\\SHAIKH MARIYA\\New folder\\hourlySteps_merged_new.csv')
hs.head()
# Out:
#            Id      ActivityHour  StepTotal
# 0  1503960366  04-12-2016 00:00        373
# 1  1503960366  04-12-2016 01:00        160
# 2  1503960366  04-12-2016 02:00        151
# 3  1503960366  04-12-2016 03:00          0
# 4  1503960366  04-12-2016 04:00          0

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   StepTotal     22099 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 518.1+ KB

# %%
hs.describe()
# Out:
#                  Id     StepTotal
# count  2.209900e+04  22099.000000
# mean   4.848235e+09    320.166342
# std    2.422500e+09    690.384228
# min    1.503960e+09      0.000000
# 25%    2.320127e+09      0.000000
# 50%    4.445115e+09     40.000000
# 75%    6.962181e+09    357.000000
# max    8.877689e+09  10554.000000

# %% [markdown]
# #### The Average Total Steps taken by the cutomers is 320.16

# %% [markdown]
# ### Analyzing the Sleep of the cutomers:

# %%
sleep=pd.read_csv('C:\\Users\\SHAIKH MARIYA\\New folder\\sleepDay_merged_new.csv')
sleep.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366       04-12-2016 00:00                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep.describe()
# Out:
#                  Id  TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# count  4.100000e+02         410.000000          410.000000      410.000000
# mean   4.994963e+09           1.119512          419.173171      458.482927
# std    2.060863e+09           0.346636          118.635918      127.455140
# min    1.503960e+09           1.000000           58.000000       61.000000
# 25%    3.977334e+09           1.000000          361.000000      403.750000
# 50%    4.702922e+09           1.000000          432.500000      463.000000
# 75%    6.962181e+09           1.000000          490.000000      526.000000
# max    8.792010e+09           3.000000          796.000000      961.000000

# %% [markdown]
# #### The Average sleep of the cutomers is 7 Hours

# %% [markdown]
# ### Analyzing the Weight of the customers:

# %%
weight=pd.read_csv('C:\\Users\\SHAIKH MARIYA\\New folder\\weightLogInfo_merged_new.csv')
weight.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366       05-02-2016 23:59   52.599998    115.963146  22.0
# 1  1503960366       05-03-2016 23:59   52.599998    115.963146   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765       05-12-2016 23:59   57.299999    126.324875   NaN
#
#          BMI  IsManualReport         LogId
# 0  22.650000            True  1.462230e+12
# 1  22.650000            True  1.462320e+12
# 2  47.540001           False  1.460510e+12
# 3  21.450001            True  1.461280e+12
# 4  21.690001            True  1.463100e+12

# %%
weight.describe()
# Out:
#                  Id    WeightKg  WeightPounds       Fat        BMI  \
# count  6.700000e+01   67.000000     67.000000   2.00000  67.000000
# mean   7.009282e+09   72.035821    158.811801  23.50000  25.185224
# std    1.950322e+09   13.923206     30.695415   2.12132   3.066963
# min    1.503960e+09   52.599998    115.963146  22.00000  21.450001
# 25%    6.962181e+09   61.400002    135.363832  22.75000  23.959999
# 50%    6.962181e+09   62.500000    137.788914  23.50000  24.389999
# 75%    8.877689e+09   85.049999    187.503152  24.25000  25.559999
# max    8.877689e+09  133.500000    294.317120  25.00000  47.540001
#
#               LogId
# count  6.700000e+01
# mean   1.461771e+12
# std    7.835136e+08
# min    1.460440e+12
# 25%    1.461080e+12
# 50%    1.461800e+12
# 75%    1.462375e+12
# max    1.463100e+12

# %% [markdown]
# #### The Average weight of the cutomers is 72kg
